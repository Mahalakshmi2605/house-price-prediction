# %%
import pandas as pd
import numpy as np

# %%
house_df = pd.read_csv("train.csv")
house_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
house_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
house_df.shape
# Out:
# (1460, 81)

# %%
house_df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
house_df.describe
# Out:
# <bound method NDFrame.describe of         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
house_df.isnull().sum().sort_values(ascending=False)
# Out:
# PoolQC           1453
# MiscFeature      1406
# Alley            1369
# Fence            1179
# MasVnrType        872
#                  ...
# MoSold              0
# YrSold              0
# SaleType            0
# SaleCondition       0
# SalePrice           0
# Length: 81, dtype: int64

# %%
#Day 02 Activity::

import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.histplot(house_df["SalePrice"],kde = True)
plt.title("SalePrice Distribution")
plt.grid()

# %%
sns.scatterplot(x = house_df["GrLivArea"], y=house_df["SalePrice"])
plt.title("Living Area Vs Price")
plt.grid()
plt.show()

# %%
sns.boxplot(x=house_df["OverallQual"],y = house_df["SalePrice"])
# Out:
# <Axes: xlabel='OverallQual', ylabel='SalePrice'>

# %%
##DAy 03 training::

corr = house_df.corr(numeric_only = True)

# %%
plt.figure(figsize = (12,8))
sns.heatmap(corr)
plt.title("Correlation Heatmap")
plt.show()

# %%
corr["SalePrice"].sort_values(ascending = False)
# Out:
# SalePrice        1.000000
# OverallQual      0.790982
# GrLivArea        0.708624
# GarageCars       0.640409
# GarageArea       0.623431
# TotalBsmtSF      0.613581
# 1stFlrSF         0.605852
# FullBath         0.560664
# TotRmsAbvGrd     0.533723
# YearBuilt        0.522897
# YearRemodAdd     0.507101
# GarageYrBlt      0.486362
# MasVnrArea       0.477493
# Fireplaces       0.466929
# BsmtFinSF1       0.386420
# LotFrontage      0.351799
# WoodDeckSF       0.324413
# 2ndFlrSF         0.319334
# OpenPorchSF      0.315856
# HalfBath         0.284108
# LotArea          0.263843
# BsmtFullBath     0.227122
# BsmtUnfSF        0.214479
# BedroomAbvGr     0.168213
# ScreenPorch      0.111447
# PoolArea         0.092404
# MoSold           0.046432
# 3SsnPorch        0.044584
# BsmtFinSF2      -0.011378
# BsmtHalfBath    -0.016844
# MiscVal         -0.021190
# Id              -0.021917
# LowQualFinSF    -0.025606
# YrSold          -0.028923
# OverallCond     -0.077856
# ...

# %%
sns.boxplot(x=house_df["OverallQual"], y=house_df["SalePrice"])

#Observation:
#As OverallQual increases, the median SalePrice increases significantly.
#Higher quality categories consistently have higher prices.
#-----------------------------
#Reason:
#Higher construction quality (materials, design, finishing) increases perceived value and buyer willingness to pay, leading to higher prices.
# Out:
# <Axes: xlabel='OverallQual', ylabel='SalePrice'>

# %%
sns.scatterplot(x = house_df["GrLivArea"],y = house_df["SalePrice"])

#Observation:
#There is a strong positive linear relationship between GrLivArea and SalePrice.
#As living area increases, house prices increase consistently, with some outliers.
#--------------------------------
#Reason:
#Larger living area provides more usable space and comfort, increasing demand and thus raising house prices.
# Out:
# <Axes: xlabel='GrLivArea', ylabel='SalePrice'>

# %%
sns.boxplot(x=house_df["GarageCars"],y=house_df["SalePrice"])
#Observation:
#SalePrice generally increases with GarageCars up to a certain point (2–3 cars), but beyond that the increase is not significant.
#----------------------------
#Reason:
#Garage capacity improves convenience and usability, but after a certain level, additional capacity does not significantly increase value, indicating diminishing returns.
# Out:
# <Axes: xlabel='GarageCars', ylabel='SalePrice'>

# %%
house_df.drop(["Alley", "MiscFeature", "Fence", "PoolQC"],axis = 1, inplace = True)

# %%
house_df.isnull().sum().sort_values(ascending=False)
# Out:
# MasVnrType       872
# FireplaceQu      690
# LotFrontage      259
# GarageFinish      81
# GarageQual        81
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 77, dtype: int64

# %%
house_df["FireplaceQu"] = house_df["FireplaceQu"].fillna("No Fireplace")

# %%
house_df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0        1          60       RL         65.0     8450   Pave      Reg
# 1        2          20       RL         80.0     9600   Pave      Reg
# 2        3          60       RL         68.0    11250   Pave      IR1
# 3        4          70       RL         60.0     9550   Pave      IR1
# 4        5          60       RL         84.0    14260   Pave      IR1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1455  1456          60       RL         62.0     7917   Pave      Reg
# 1456  1457          20       RL         85.0    13175   Pave      Reg
# 1457  1458          70       RL         66.0     9042   Pave      Reg
# 1458  1459          20       RL         68.0     9717   Pave      Reg
# 1459  1460          20       RL         75.0     9937   Pave      Reg
#
#      LandContour Utilities LotConfig  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# ...

# %%
house_df["LotFrontage"] = house_df["LotFrontage"].fillna(house_df["LotFrontage"].median())

# %%
house_df["MasVnrArea"] = house_df["MasVnrArea"].fillna(house_df["MasVnrArea"].median())

# %%
house_df["MasVnrType"] = house_df["MasVnrType"].fillna("None")

# %%
house_df.isnull().sum().sort_values()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
#                 ..
# GarageCond      81
# GarageQual      81
# GarageYrBlt     81
# GarageFinish    81
# GarageType      81
# Length: 77, dtype: int64

# %%
house_df["GarageType"] = house_df["GarageType"].fillna("No Garage")

# %%
house_df["GarageFinish"] = house_df["GarageFinish"].fillna("No Garage")

# %%
house_df["GarageQual"] = house_df["GarageQual"].fillna("No Garage")

# %%
house_df["GarageCond"] = house_df["GarageCond"].fillna("No Garage")

# %%
house_df["GarageYrBlt"] = house_df["GarageYrBlt"].fillna(0)

# %%
house_df.isnull().sum().sort_values(ascending = False)
# Out:
# BsmtFinType2     38
# BsmtExposure     38
# BsmtQual         37
# BsmtCond         37
# BsmtFinType1     37
#                  ..
# MoSold            0
# YrSold            0
# SaleType          0
# SaleCondition     0
# SalePrice         0
# Length: 77, dtype: int64

# %%
house_df["BsmtFinType2"] = house_df["BsmtFinType2"].fillna("No Basement")

# %%
house_df["BsmtExposure"] = house_df["BsmtExposure"].fillna("No Basement")

# %%
house_df["BsmtQual"] = house_df["BsmtQual"].fillna("No Basement")
house_df["BsmtCond"] = house_df["BsmtCond"].fillna("No Basement")
house_df["BsmtFinType1"] = house_df["BsmtFinType1"].fillna("No Basement")

# %%
house_df["Electrical"] = house_df["Electrical"].fillna(house_df["Electrical"].mode()[0])

# %%
house_df.isnull().sum().sort_values(ascending = False)
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 77, dtype: int64

# %%
cat_cols = house_df.select_dtypes(include=["object"]).columns
cat_cols
# Out:
# Index(['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
house_df = pd.get_dummies(house_df,columns = cat_cols,drop_first = True)

# %%
house_df.shape
# Out:
# (1460, 248)

# %%
house_df.corr()["SalePrice"].sort_values(ascending = False)
# Out:
# SalePrice                   1.000000
# OverallQual                 0.790982
# GrLivArea                   0.708624
# GarageCars                  0.640409
# GarageArea                  0.623431
#                               ...
# GarageFinish_Unf           -0.410608
# BsmtQual_TA                -0.452394
# FireplaceQu_No Fireplace   -0.471908
# KitchenQual_TA             -0.519298
# ExterQual_TA               -0.589044
# Name: SalePrice, Length: 248, dtype: float64

# %%
corl = house_df.corr(numeric_only = True)["SalePrice"].sort_values(ascending = False)
corl.head(15)
# Out:
# SalePrice           1.000000
# OverallQual         0.790982
# GrLivArea           0.708624
# GarageCars          0.640409
# GarageArea          0.623431
# TotalBsmtSF         0.613581
# 1stFlrSF            0.605852
# FullBath            0.560664
# TotRmsAbvGrd        0.533723
# YearBuilt           0.522897
# YearRemodAdd        0.507101
# Foundation_PConc    0.497734
# MasVnrArea          0.472614
# Fireplaces          0.466929
# ExterQual_Gd        0.452466
# Name: SalePrice, dtype: float64

# %%
## DAY - 08 (Splitting Data)

X = house_df.drop("SalePrice" , axis = 1)
Y = house_df["SalePrice"]

# %%
X.shape,Y.shape
# Out:
# ((1460, 247), (1460,))

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 42)

# %%
X_train.shape,X_test.shape
# Out:
# ((1168, 247), (292, 247))

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
model.coef_
# Out:
# array([ 6.93829034e-01,  5.49765783e+01,  3.09243664e+01,  6.50587441e-01,
#         6.74572184e+03,  5.72474594e+03,  3.52960643e+02,  1.31872049e+02,
#         2.13941104e+01,  1.79185594e+01,  7.86744618e+00, -1.55949709e-01,
#         2.56296487e+01,  9.97627635e+00,  3.05624469e+01, -1.04116955e+01,
#         3.01266507e+01,  1.36304180e+03, -1.59283556e+03,  2.82954629e+03,
#         1.35797657e+03, -2.60195793e+03, -1.27569135e+04,  1.42173474e+03,
#         6.51761479e+03, -3.23390361e+01,  1.35798897e+03,  3.03186003e+01,
#         1.55550750e+01, -6.46309024e-01,  2.00514908e+00,  5.04501072e+01,
#         2.52813555e+01,  7.80485170e+01, -2.22484382e-01, -4.19630062e+02,
#        -2.49865061e+02,  2.99152845e+04,  1.87948794e+04,  2.08149525e+04,
#         2.19551768e+04,  2.24013022e+04,  6.63254767e+03,  7.63471023e+03,
#         1.57961693e+03,  1.35970404e+04, -8.33705401e+03,  3.78620972e+03,
# ...

# %%
model.intercept_
# Out:
# np.float64(-1128498.7656603088)

# %%
y_pred = model.predict(X_test)

# %%
Y_test[:5]
# Out:
# 892     154500
# 1105    325000
# 413     115000
# 522     159000
# 1036    315500
# Name: SalePrice, dtype: int64

# %%
y_pred[:5]
# Out:
# array([157434.78320941, 354827.54955748,  86960.65652143, 179675.50411192,
#        321553.64960316])

# %%
from sklearn.metrics import mean_squared_error

rmse = np.sqrt(mean_squared_error(Y_test,y_pred))
rmse
# Out:
# np.float64(52529.842442258385)

# %%
#Import
from sklearn.preprocessing import StandardScaler
#Create Scaler
scaler = StandardScaler()
#Fit and Transform
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

#Train Model
model.fit(X_train_scaled, Y_train)
y_pred_scaled = model.predict(X_test_scaled)

rmse_scaled = np.sqrt(mean_squared_error(Y_test,y_pred_scaled))
rmse_scaled
# Out:
# np.float64(52529.842442243345)

# %%
from sklearn.ensemble import RandomForestRegressor

rf_model = RandomForestRegressor(n_estimators = 100, random_state = 82)
rf_model.fit(X_train,Y_train)
y_pred_rf = rf_model.predict(X_test)
rmse_rf = np.sqrt(mean_squared_error(Y_test, y_pred_rf))
rmse_rf
# Out:
# np.float64(29372.163119942852)

# %%
rf_model_modify = RandomForestRegressor(n_estimators = 100, max_depth = 10, min_samples_split = 5,random_state = 82)
rf_model_modify.fit(X_train, Y_train)
y_pred_rf_mod = rf_model.predict(X_test)
rmse_rf_modify = np.sqrt(mean_squared_error(Y_test,y_pred_rf_mod))
rmse_rf_modify
# Out:
# np.float64(29372.163119942852)

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = { "n_estimators" : [50,100],
                "max_depth" : [None, 10, 20],
              "min_samples_split" : [2,5]}

# %%
rf = RandomForestRegressor(random_state=82)
grid_search = GridSearchCV(
    estimator = rf,
    param_grid = param_grid,
    cv = 3,
    scoring = "neg_mean_squared_error",
    n_jobs = -1)

# %%
grid_search.fit(X_train, Y_train)
# Out:
# GridSearchCV(cv=3, estimator=RandomForestRegressor(random_state=82), n_jobs=-1,
#              param_grid={'max_depth': [None, 10, 20],
#                          'min_samples_split': [2, 5],
#                          'n_estimators': [50, 100]},
#              scoring='neg_mean_squared_error')

# %%
grid_search.best_params_
# Out:
# {'max_depth': 20, 'min_samples_split': 2, 'n_estimators': 50}

# %%
best_model = grid_search.best_estimator_
y_pred_best = best_model.predict(X_test)
rmse_best = np.sqrt(mean_squared_error(Y_test,y_pred_best))
rmse_best
# Out:
# np.float64(30066.178597264967)

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(
    rf_model,
    X,
    Y,
    scoring = "neg_mean_squared_error",
    cv = 5)

rmse_scores = np.sqrt(-scores)
rmse_scores
# Out:
# array([27756.58793258, 31692.44124277, 30965.03293498, 24843.99351566,
#        34802.79024914])

# %%
rmse_scores.mean()
# Out:
# np.float64(30012.169175025796)

# %%
feature_importances = pd.Series(rf_model.feature_importances_,
                                index = X.columns)

# %%
feature_importances.sort_values(ascending = False).head(10)
# Out:
# OverallQual    0.554464
# GrLivArea      0.126043
# 2ndFlrSF       0.032915
# TotalBsmtSF    0.031593
# 1stFlrSF       0.030320
# BsmtFinSF1     0.029549
# GarageCars     0.018636
# LotArea        0.018144
# GarageArea     0.013408
# YearBuilt      0.012533
# dtype: float64

# %%
import matplotlib.pyplot as plt

models = ["Linear Regression", "Random Forest"]
rmse = [52530, 29372]

plt.bar(models, rmse)
plt.title("RMSE Comparison")
plt.ylabel("RMSE")

plt.savefig("rmse_comparison.png")
plt.show()
